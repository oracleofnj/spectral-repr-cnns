# %%
import numpy as np
import tensorflow as tf
import matplotlib.pylab as plt

from modules.utils import load_cifar10
from modules.cnn_with_spectral_pooling import CNN_Spectral_Pool

% matplotlib inline
% load_ext autoreload
% autoreload 2

# %% [markdown]
# # Download CIFAR data, if necessary, and load it

# %%
xtrain, ytrain, xtest, ytest = load_cifar10(5, get_test_data=True, channels_last=False)
# Out:
# file already downloaded..
# getting batch 1
# getting batch 2
# getting batch 3
# getting batch 4
# getting batch 5

# %%
xtrain.shape, ytrain.shape, xtest.shape, ytest.shape
# Out:
# ((50000, 3, 32, 32), (50000,), (10000, 3, 32, 32), (10000,))

# %% [markdown]
# # Subsample the data for hyperparameter search

# %%
sample_size = 2 ** 14
sampleind = np.random.choice(np.arange(xtrain.shape[0]),
                             size=sample_size, replace=False)
xtrain_sample = xtrain[sampleind]
ytrain_sample = ytrain[sampleind]
xtrain_sample.shape, ytrain_sample.shape
# Out:
# ((16384, 3, 32, 32), (16384,))

# %% [markdown]
# # Define ranges for hyperparameters

# %%
learning_rate_range = [1e-5, 2e-3]
l2_norm_range = [1e-5, 1e-2]
M_range = [3, 9]
gamma_range = [0.5, 0.9]

# %% [markdown]
# # Perform the hyperparameter search

# %%
validation_size = 2 ** 10
hyperparams = []
best_accuracies = []
full_model_names = [] 
for search_idx in range(10):
    learning_rate = np.exp(np.random.uniform(
        low=np.log(learning_rate_range[0]),
        high=np.log(learning_rate_range[1])
    ))
    l2_norm = np.exp(np.random.uniform(
        low=np.log(l2_norm_range[0]),
        high=np.log(l2_norm_range[1])
    ))
    M = np.random.randint(
        low = M_range[0],
        high = M_range[1] + 1
    )
    gamma = np.random.uniform(
        low = gamma_range[0],
        high = gamma_range[1]
    )
    hyperparams.append({
        'learning_rate': learning_rate,
        'l2_norm': l2_norm,
        'M': M,
        'gamma': gamma,
    })
    tf.reset_default_graph()
    cnn = CNN_Spectral_Pool(M=M,
                            num_output=10,
                            verbose=False,
                            learning_rate=learning_rate,
                            l2_norm=l2_norm,
                            lr_reduction_factor=0.5,
                            lr_reduction_epochs=[11,21,31,41],
                            gamma=gamma)
    print('Trying hyperparameters: ')
    print(hyperparams[-1])
    cnn.train(xtrain_sample[:-validation_size],
              ytrain_sample[:-validation_size],
              xtrain_sample[-validation_size:],
              ytrain_sample[-validation_size:],
              batch_size=256,
              epochs=30,
              extra_conv_layer=True,
              use_global_averaging=True,
              model_name='hyperparam_search'
    )
    best_accuracies.append(cnn.best_acc)
    full_model_names.append(cnn.full_model_name)
    
print('Overall best accuracy: {0:.3f}'.format(np.max(best_accuracies)))
print('Full Model Name: {0}'.format(full_model_names[np.argmax(best_accuracies)]))
print('Hyperparameters achieving this result: ')
print(hyperparams[np.argmax(best_accuracies)])
# Out:
# Trying hyperparameters:
# {'l2_norm': 0.0024856655044985746, 'M': 7, 'learning_rate': 0.0014706372136129031, 'gamma': 0.6315427063962382}
# Building tf graph...
# (?, 10)
# number of batches for training: 60 validation: 4
# training epoch 1
#
# 	Best validation accuracy! iteration:60 accuracy: 19.140625%
#
# training epoch 2
#
# 	Best validation accuracy! iteration:120 accuracy: 22.16796875%
#
# training epoch 3
#
# 	Best validation accuracy! iteration:180 accuracy: 26.26953125%
#
# training epoch 4
#
# 	Best validation accuracy! iteration:240 accuracy: 32.12890625%
#
# training epoch 5
#
# 	Best validation accuracy! iteration:300 accuracy: 33.3984375%
#
# training epoch 6
#
# 	Best validation accuracy! iteration:360 accuracy: 38.671875%
#
# training epoch 7
#
# 	Best validation accuracy! iteration:420 accuracy: 41.30859375%
#
# training epoch 8
#
# 	Best validation accuracy! iteration:480 accuracy: 42.28515625%
#
# training epoch 9
#
# 	Best validation accuracy! iteration:540 accuracy: 42.67578125%
#
# training epoch 10
#
# 	Best validation accuracy! iteration:600 accuracy: 45.8984375%
#
# training epoch 11
#
# 	Best validation accuracy! iteration:660 accuracy: 49.51171875%
#
# training epoch 12
# training epoch 13
# training epoch 14
#
# 	Best validation accuracy! iteration:840 accuracy: 52.44140625%
#
# training epoch 15
# training epoch 16
#
# 	Best validation accuracy! iteration:960 accuracy: 53.41796875%
#
# training epoch 17
# training epoch 18
# training epoch 19
#
# 	Best validation accuracy! iteration:1140 accuracy: 53.7109375%
#
# training epoch 20
#
# 	Best validation accuracy! iteration:1200 accuracy: 54.00390625%
#
# training epoch 21
#
# 	Best validation accuracy! iteration:1260 accuracy: 54.6875%
#
# training epoch 22
#
# 	Best validation accuracy! iteration:1320 accuracy: 55.078125%
#
# training epoch 23
#
# 	Best validation accuracy! iteration:1380 accuracy: 55.76171875%
#
# training epoch 24
# training epoch 25
#
# 	Best validation accuracy! iteration:1500 accuracy: 56.4453125%
#
# training epoch 26
#
# 	Best validation accuracy! iteration:1560 accuracy: 58.30078125%
#
# training epoch 27
#
# 	Best validation accuracy! iteration:1620 accuracy: 59.375%
#
# training epoch 28
# training epoch 29
# training epoch 30
# Best validation accuracy: 59.375%; Model name: 'hyperparam_search/hyperparam_search_1513527144.275317'.
# Trying hyperparameters:
# {'l2_norm': 0.00043117338763034777, 'M': 8, 'learning_rate': 0.00025883920393689045, 'gamma': 0.7384631646885785}
# Building tf graph...
# (?, 10)
# number of batches for training: 60 validation: 4
# training epoch 1
#
# 	Best validation accuracy! iteration:60 accuracy: 24.0234375%
#
# training epoch 2
#
# 	Best validation accuracy! iteration:120 accuracy: 29.00390625%
#
# training epoch 3
#
# 	Best validation accuracy! iteration:180 accuracy: 37.01171875%
#
# training epoch 4
#
# 	Best validation accuracy! iteration:240 accuracy: 38.37890625%
#
# training epoch 5
#
# 	Best validation accuracy! iteration:300 accuracy: 43.45703125%
#
# training epoch 6
#
# 	Best validation accuracy! iteration:360 accuracy: 44.53125%
#
# training epoch 7
#
# 	Best validation accuracy! iteration:420 accuracy: 46.58203125%
#
# training epoch 8
# training epoch 9
#
# 	Best validation accuracy! iteration:540 accuracy: 49.70703125%
#
# training epoch 10
#
# 	Best validation accuracy! iteration:600 accuracy: 52.5390625%
#
# training epoch 11
#
# 	Best validation accuracy! iteration:660 accuracy: 54.19921875%
#
# training epoch 12
#
# 	Best validation accuracy! iteration:720 accuracy: 56.0546875%
#
# training epoch 13
# training epoch 14
#
# 	Best validation accuracy! iteration:840 accuracy: 57.32421875%
#
# training epoch 15
# training epoch 16
#
# 	Best validation accuracy! iteration:960 accuracy: 58.7890625%
#
# training epoch 17
#
# 	Best validation accuracy! iteration:1020 accuracy: 59.9609375%
#
# training epoch 18
#
# 	Best validation accuracy! iteration:1080 accuracy: 60.83984375%
#
# training epoch 19
# training epoch 20
# training epoch 21
#
# 	Best validation accuracy! iteration:1260 accuracy: 61.328125%
#
# training epoch 22
# training epoch 23
# training epoch 24
# training epoch 25
#
# 	Best validation accuracy! iteration:1500 accuracy: 61.9140625%
#
# training epoch 26
# training epoch 27
# training epoch 28
#
# 	Best validation accuracy! iteration:1680 accuracy: 62.5%
#
# training epoch 29
# training epoch 30
# Best validation accuracy: 62.500%; Model name: 'hyperparam_search/hyperparam_search_1513528057.088582'.
# Trying hyperparameters:
# {'l2_norm': 1.0285853191946928e-05, 'M': 4, 'learning_rate': 6.8145722853001637e-05, 'gamma': 0.8205800355329975}
# Building tf graph...
# (?, 10)
# number of batches for training: 60 validation: 4
# training epoch 1
#
# 	Best validation accuracy! iteration:60 accuracy: 22.75390625%
#
# training epoch 2
#
# 	Best validation accuracy! iteration:120 accuracy: 27.63671875%
#
# training epoch 3
#
# 	Best validation accuracy! iteration:180 accuracy: 29.58984375%
#
# training epoch 4
#
# 	Best validation accuracy! iteration:240 accuracy: 32.421875%
#
# training epoch 5
#
# 	Best validation accuracy! iteration:300 accuracy: 33.984375%
#
# training epoch 6
#
# 	Best validation accuracy! iteration:360 accuracy: 35.25390625%
#
# training epoch 7
#
# 	Best validation accuracy! iteration:420 accuracy: 35.7421875%
#
# training epoch 8
#
# 	Best validation accuracy! iteration:480 accuracy: 36.9140625%
#
# training epoch 9
#
# 	Best validation accuracy! iteration:540 accuracy: 37.40234375%
#
# training epoch 10
# training epoch 11
#
# 	Best validation accuracy! iteration:660 accuracy: 39.55078125%
#
# training epoch 12
# training epoch 13
# training epoch 14
#
# 	Best validation accuracy! iteration:840 accuracy: 40.0390625%
#
# training epoch 15
#
# 	Best validation accuracy! iteration:900 accuracy: 40.625%
#
# training epoch 16
# training epoch 17
#
# 	Best validation accuracy! iteration:1020 accuracy: 40.91796875%
#
# training epoch 18
#
# 	Best validation accuracy! iteration:1080 accuracy: 41.015625%
#
# training epoch 19
#
# 	Best validation accuracy! iteration:1140 accuracy: 41.11328125%
#
# training epoch 20
#
# 	Best validation accuracy! iteration:1200 accuracy: 41.40625%
#
# training epoch 21
#
# 	Best validation accuracy! iteration:1260 accuracy: 42.7734375%
#
# training epoch 22
# training epoch 23
# training epoch 24
# training epoch 25
# training epoch 26
# training epoch 27
# training epoch 28
#
# 	Best validation accuracy! iteration:1680 accuracy: 43.75%
#
# training epoch 29
# training epoch 30
# Best validation accuracy: 43.750%; Model name: 'hyperparam_search/hyperparam_search_1513528987.5366926'.
# Trying hyperparameters:
# {'l2_norm': 5.68126794801682e-05, 'M': 9, 'learning_rate': 0.00030784261205004797, 'gamma': 0.7233634290843051}
# Building tf graph...
# (?, 10)
# number of batches for training: 60 validation: 4
# training epoch 1
#
# 	Best validation accuracy! iteration:60 accuracy: 24.4140625%
#
# training epoch 2
#
# 	Best validation accuracy! iteration:120 accuracy: 28.41796875%
#
# training epoch 3
#
# 	Best validation accuracy! iteration:180 accuracy: 34.9609375%
#
# training epoch 4
# training epoch 5
#
# 	Best validation accuracy! iteration:300 accuracy: 40.33203125%
#
# training epoch 6
#
# 	Best validation accuracy! iteration:360 accuracy: 44.23828125%
#
# training epoch 7
# training epoch 8
#
# 	Best validation accuracy! iteration:480 accuracy: 47.0703125%
#
# training epoch 9
#
# 	Best validation accuracy! iteration:540 accuracy: 51.26953125%
#
# training epoch 10
# training epoch 11
#
# 	Best validation accuracy! iteration:660 accuracy: 52.9296875%
#
# training epoch 12
#
# 	Best validation accuracy! iteration:720 accuracy: 55.6640625%
#
# training epoch 13
# training epoch 14
#
# 	Best validation accuracy! iteration:840 accuracy: 56.93359375%
#
# training epoch 15
#
# 	Best validation accuracy! iteration:900 accuracy: 57.421875%
#
# training epoch 16
#
# 	Best validation accuracy! iteration:960 accuracy: 59.47265625%
#
# training epoch 17
# training epoch 18
# training epoch 19
# training epoch 20
# training epoch 21
#
# 	Best validation accuracy! iteration:1260 accuracy: 60.44921875%
#
# training epoch 22
#
# 	Best validation accuracy! iteration:1320 accuracy: 61.23046875%
#
# training epoch 23
#
# 	Best validation accuracy! iteration:1380 accuracy: 62.01171875%
#
# training epoch 24
#
# 	Best validation accuracy! iteration:1440 accuracy: 62.5%
#
# training epoch 25
# training epoch 26
# training epoch 27
# training epoch 28
# training epoch 29
# training epoch 30
# Best validation accuracy: 62.500%; Model name: 'hyperparam_search/hyperparam_search_1513529916.8443604'.
# Trying hyperparameters:
# {'l2_norm': 2.7041295917456897e-05, 'M': 7, 'learning_rate': 0.0010865895925234851, 'gamma': 0.6335837941219958}
# Building tf graph...
# (?, 10)
# number of batches for training: 60 validation: 4
# training epoch 1
#
# 	Best validation accuracy! iteration:60 accuracy: 20.5078125%
#
# training epoch 2
#
# 	Best validation accuracy! iteration:120 accuracy: 29.1015625%
#
# training epoch 3
#
# 	Best validation accuracy! iteration:180 accuracy: 29.19921875%
#
# training epoch 4
#
# 	Best validation accuracy! iteration:240 accuracy: 37.79296875%
#
# training epoch 5
#
# 	Best validation accuracy! iteration:300 accuracy: 41.69921875%
#
# training epoch 6
#
# 	Best validation accuracy! iteration:360 accuracy: 46.09375%
#
# training epoch 7
#
# 	Best validation accuracy! iteration:420 accuracy: 47.75390625%
#
# training epoch 8
#
# 	Best validation accuracy! iteration:480 accuracy: 48.92578125%
#
# training epoch 9
#
# 	Best validation accuracy! iteration:540 accuracy: 52.9296875%
#
# training epoch 10
#
# 	Best validation accuracy! iteration:600 accuracy: 54.78515625%
#
# training epoch 11
#
# 	Best validation accuracy! iteration:660 accuracy: 55.76171875%
#
# training epoch 12
# training epoch 13
#
# 	Best validation accuracy! iteration:780 accuracy: 56.0546875%
#
# training epoch 14
#
# 	Best validation accuracy! iteration:840 accuracy: 57.421875%
#
# training epoch 15
#
# 	Best validation accuracy! iteration:900 accuracy: 58.30078125%
#
# training epoch 16
#
# 	Best validation accuracy! iteration:960 accuracy: 59.1796875%
#
# training epoch 17
# training epoch 18
#
# 	Best validation accuracy! iteration:1080 accuracy: 59.375%
#
# training epoch 19
#
# 	Best validation accuracy! iteration:1140 accuracy: 60.25390625%
#
# training epoch 20
#
# 	Best validation accuracy! iteration:1200 accuracy: 60.546875%
#
# training epoch 21
# training epoch 22
# training epoch 23
#
# 	Best validation accuracy! iteration:1380 accuracy: 62.3046875%
#
# training epoch 24
# training epoch 25
#
# 	Best validation accuracy! iteration:1500 accuracy: 62.59765625%
#
# training epoch 26
# training epoch 27
# training epoch 28
# training epoch 29
#
# 	Best validation accuracy! iteration:1740 accuracy: 63.57421875%
#
# training epoch 30
# Best validation accuracy: 63.574%; Model name: 'hyperparam_search/hyperparam_search_1513530707.2960517'.
# Trying hyperparameters:
# {'l2_norm': 0.00015550028231793703, 'M': 8, 'learning_rate': 7.1157525646938503e-05, 'gamma': 0.7856013494091891}
# Building tf graph...
# (?, 10)
# number of batches for training: 60 validation: 4
# training epoch 1
#
# 	Best validation accuracy! iteration:60 accuracy: 28.02734375%
#
# training epoch 2
#
# 	Best validation accuracy! iteration:120 accuracy: 31.0546875%
#
# training epoch 3
#
# 	Best validation accuracy! iteration:180 accuracy: 37.01171875%
#
# training epoch 4
#
# 	Best validation accuracy! iteration:240 accuracy: 40.8203125%
#
# training epoch 5
#
# 	Best validation accuracy! iteration:300 accuracy: 42.28515625%
#
# training epoch 6
#
# 	Best validation accuracy! iteration:360 accuracy: 45.21484375%
#
# training epoch 7
# training epoch 8
#
# 	Best validation accuracy! iteration:480 accuracy: 47.4609375%
#
# training epoch 9
# training epoch 10
# training epoch 11
#
# 	Best validation accuracy! iteration:660 accuracy: 49.8046875%
#
# training epoch 12
#
# 	Best validation accuracy! iteration:720 accuracy: 50.1953125%
#
# training epoch 13
#
# 	Best validation accuracy! iteration:780 accuracy: 51.171875%
#
# training epoch 14
# training epoch 15
#
# 	Best validation accuracy! iteration:900 accuracy: 51.66015625%
#
# training epoch 16
#
# 	Best validation accuracy! iteration:960 accuracy: 53.02734375%
#
# training epoch 17
# training epoch 18
# training epoch 19
#
# 	Best validation accuracy! iteration:1140 accuracy: 53.515625%
#
# training epoch 20
# training epoch 21
#
# 	Best validation accuracy! iteration:1260 accuracy: 54.78515625%
#
# training epoch 22
# training epoch 23
#
# 	Best validation accuracy! iteration:1380 accuracy: 55.859375%
#
# training epoch 24
# training epoch 25
# training epoch 26
# training epoch 27
#
# 	Best validation accuracy! iteration:1620 accuracy: 55.95703125%
#
# training epoch 28
# training epoch 29
# training epoch 30
#
# 	Best validation accuracy! iteration:1800 accuracy: 56.25%
#
# Best validation accuracy: 56.250%; Model name: 'hyperparam_search/hyperparam_search_1513531594.357941'.
# Trying hyperparameters:
# {'l2_norm': 0.0005546182368876126, 'M': 9, 'learning_rate': 0.00016399035514633246, 'gamma': 0.840481974353574}
# Building tf graph...
# (?, 10)
# number of batches for training: 60 validation: 4
# training epoch 1
#
# 	Best validation accuracy! iteration:60 accuracy: 22.36328125%
#
# training epoch 2
#
# 	Best validation accuracy! iteration:120 accuracy: 30.76171875%
#
# training epoch 3
#
# 	Best validation accuracy! iteration:180 accuracy: 33.30078125%
#
# training epoch 4
#
# 	Best validation accuracy! iteration:240 accuracy: 40.4296875%
#
# training epoch 5
# training epoch 6
# training epoch 7
#
# 	Best validation accuracy! iteration:420 accuracy: 47.16796875%
#
# training epoch 8
# training epoch 9
#
# 	Best validation accuracy! iteration:540 accuracy: 49.31640625%
#
# training epoch 10
#
# 	Best validation accuracy! iteration:600 accuracy: 51.3671875%
#
# training epoch 11
#
# 	Best validation accuracy! iteration:660 accuracy: 53.7109375%
#
# training epoch 12
#
# 	Best validation accuracy! iteration:720 accuracy: 55.95703125%
#
# training epoch 13
# training epoch 14
#
# 	Best validation accuracy! iteration:840 accuracy: 56.4453125%
#
# training epoch 15
# training epoch 16
#
# 	Best validation accuracy! iteration:960 accuracy: 57.91015625%
#
# training epoch 17
# training epoch 18
# training epoch 19
# training epoch 20
#
# 	Best validation accuracy! iteration:1200 accuracy: 58.7890625%
#
# training epoch 21
#
# 	Best validation accuracy! iteration:1260 accuracy: 59.1796875%
#
# training epoch 22
# training epoch 23
#
# 	Best validation accuracy! iteration:1380 accuracy: 59.47265625%
#
# training epoch 24
# training epoch 25
#
# 	Best validation accuracy! iteration:1500 accuracy: 60.64453125%
#
# training epoch 26
#
# 	Best validation accuracy! iteration:1560 accuracy: 60.9375%
#
# training epoch 27
# training epoch 28
#
# 	Best validation accuracy! iteration:1680 accuracy: 61.9140625%
#
# training epoch 29
# training epoch 30
#
# 	Best validation accuracy! iteration:1800 accuracy: 62.98828125%
#
# Best validation accuracy: 62.988%; Model name: 'hyperparam_search/hyperparam_search_1513532696.2902846'.
# Trying hyperparameters:
# {'l2_norm': 0.00021256713201248066, 'M': 4, 'learning_rate': 0.0002472721891012964, 'gamma': 0.7049601286487712}
# Building tf graph...
# (?, 10)
# number of batches for training: 60 validation: 4
# training epoch 1
#
# 	Best validation accuracy! iteration:60 accuracy: 30.17578125%
#
# training epoch 2
#
# 	Best validation accuracy! iteration:120 accuracy: 33.3984375%
#
# training epoch 3
#
# 	Best validation accuracy! iteration:180 accuracy: 36.81640625%
#
# training epoch 4
#
# 	Best validation accuracy! iteration:240 accuracy: 37.79296875%
#
# training epoch 5
#
# 	Best validation accuracy! iteration:300 accuracy: 41.30859375%
#
# training epoch 6
# training epoch 7
#
# 	Best validation accuracy! iteration:420 accuracy: 42.96875%
#
# training epoch 8
#
# 	Best validation accuracy! iteration:480 accuracy: 43.45703125%
#
# training epoch 9
#
# 	Best validation accuracy! iteration:540 accuracy: 47.65625%
#
# training epoch 10
# training epoch 11
#
# 	Best validation accuracy! iteration:660 accuracy: 48.14453125%
#
# training epoch 12
#
# 	Best validation accuracy! iteration:720 accuracy: 48.828125%
#
# training epoch 13
#
# 	Best validation accuracy! iteration:780 accuracy: 51.171875%
#
# training epoch 14
#
# 	Best validation accuracy! iteration:840 accuracy: 51.5625%
#
# training epoch 15
#
# 	Best validation accuracy! iteration:900 accuracy: 52.5390625%
#
# training epoch 16
# training epoch 17
#
# 	Best validation accuracy! iteration:1020 accuracy: 52.734375%
#
# training epoch 18
#
# 	Best validation accuracy! iteration:1080 accuracy: 53.7109375%
#
# training epoch 19
# training epoch 20
# training epoch 21
#
# 	Best validation accuracy! iteration:1260 accuracy: 54.296875%
#
# training epoch 22
# training epoch 23
# training epoch 24
#
# 	Best validation accuracy! iteration:1440 accuracy: 54.8828125%
#
# training epoch 25
# training epoch 26
# training epoch 27
# training epoch 28
#
# 	Best validation accuracy! iteration:1680 accuracy: 55.95703125%
#
# training epoch 29
# training epoch 30
# Best validation accuracy: 55.957%; Model name: 'hyperparam_search/hyperparam_search_1513534289.9995794'.
# Trying hyperparameters:
# {'l2_norm': 0.00841930997422001, 'M': 8, 'learning_rate': 0.0010452604748449087, 'gamma': 0.8741925404421038}
# Building tf graph...
# (?, 10)
# number of batches for training: 60 validation: 4
# training epoch 1
#
# 	Best validation accuracy! iteration:60 accuracy: 10.05859375%
#
# training epoch 2
#
# 	Best validation accuracy! iteration:120 accuracy: 20.60546875%
#
# training epoch 3
# training epoch 4
#
# 	Best validation accuracy! iteration:240 accuracy: 23.92578125%
#
# training epoch 5
# training epoch 6
#
# 	Best validation accuracy! iteration:360 accuracy: 26.66015625%
#
# training epoch 7
#
# 	Best validation accuracy! iteration:420 accuracy: 29.19921875%
#
# training epoch 8
#
# 	Best validation accuracy! iteration:480 accuracy: 29.4921875%
#
# training epoch 9
#
# 	Best validation accuracy! iteration:540 accuracy: 30.37109375%
#
# training epoch 10
# training epoch 11
#
# 	Best validation accuracy! iteration:660 accuracy: 32.8125%
#
# training epoch 12
# training epoch 13
#
# 	Best validation accuracy! iteration:780 accuracy: 34.1796875%
#
# training epoch 14
#
# 	Best validation accuracy! iteration:840 accuracy: 34.5703125%
#
# training epoch 15
#
# 	Best validation accuracy! iteration:900 accuracy: 35.83984375%
#
# training epoch 16
# training epoch 17
#
# 	Best validation accuracy! iteration:1020 accuracy: 36.328125%
#
# training epoch 18
# training epoch 19
# training epoch 20
#
# 	Best validation accuracy! iteration:1200 accuracy: 38.57421875%
#
# training epoch 21
# training epoch 22
# training epoch 23
# training epoch 24
#
# 	Best validation accuracy! iteration:1440 accuracy: 39.2578125%
#
# training epoch 25
#
# 	Best validation accuracy! iteration:1500 accuracy: 40.0390625%
#
# training epoch 26
# training epoch 27
# training epoch 28
# training epoch 29
#
# 	Best validation accuracy! iteration:1740 accuracy: 40.91796875%
#
# training epoch 30
# Best validation accuracy: 40.918%; Model name: 'hyperparam_search/hyperparam_search_1513535153.7398098'.
# Trying hyperparameters:
# {'l2_norm': 8.7832208812313911e-05, 'M': 3, 'learning_rate': 0.00042747930905791525, 'gamma': 0.6219362212512273}
# Building tf graph...
# (?, 10)
# number of batches for training: 60 validation: 4
# training epoch 1
#
# 	Best validation accuracy! iteration:60 accuracy: 27.9296875%
#
# training epoch 2
#
# 	Best validation accuracy! iteration:120 accuracy: 32.12890625%
#
# training epoch 3
#
# 	Best validation accuracy! iteration:180 accuracy: 38.18359375%
#
# training epoch 4
#
# 	Best validation accuracy! iteration:240 accuracy: 41.11328125%
#
# training epoch 5
#
# 	Best validation accuracy! iteration:300 accuracy: 42.08984375%
#
# training epoch 6
#
# 	Best validation accuracy! iteration:360 accuracy: 42.96875%
#
# training epoch 7
#
# 	Best validation accuracy! iteration:420 accuracy: 43.1640625%
#
# training epoch 8
#
# 	Best validation accuracy! iteration:480 accuracy: 45.41015625%
#
# training epoch 9
# training epoch 10
#
# 	Best validation accuracy! iteration:600 accuracy: 45.99609375%
#
# training epoch 11
#
# 	Best validation accuracy! iteration:660 accuracy: 49.12109375%
#
# training epoch 12
# training epoch 13
# training epoch 14
#
# 	Best validation accuracy! iteration:840 accuracy: 49.51171875%
#
# training epoch 15
#
# 	Best validation accuracy! iteration:900 accuracy: 50.1953125%
#
# training epoch 16
#
# 	Best validation accuracy! iteration:960 accuracy: 50.29296875%
#
# training epoch 17
# training epoch 18
#
# 	Best validation accuracy! iteration:1080 accuracy: 50.78125%
#
# training epoch 19
#
# 	Best validation accuracy! iteration:1140 accuracy: 52.63671875%
#
# training epoch 20
#
# 	Best validation accuracy! iteration:1200 accuracy: 52.9296875%
#
# training epoch 21
# training epoch 22
#
# 	Best validation accuracy! iteration:1320 accuracy: 53.41796875%
#
# training epoch 23
#
# 	Best validation accuracy! iteration:1380 accuracy: 53.61328125%
#
# training epoch 24
# training epoch 25
# training epoch 26
#
# 	Best validation accuracy! iteration:1560 accuracy: 54.6875%
#
# training epoch 27
# training epoch 28
# training epoch 29
# training epoch 30
# Best validation accuracy: 54.688%; Model name: 'hyperparam_search/hyperparam_search_1513537644.5347779'.
# Overall best accuracy: 63.574
# Full Model Name: hyperparam_search_1513530707.2960517
# Hyperparameters achieving this result:
# {'l2_norm': 2.7041295917456897e-05, 'M': 7, 'learning_rate': 0.0010865895925234851, 'gamma': 0.6335837941219958}

# %% [markdown]
# __Note:__ We performed the hyperparameter search across multiple GPU instances. This notebook shows the parameter search that resulted in the best hyperparameters across all the instances we ran.

# %%
tf.reset_default_graph()
overall_best_model = full_model_names[np.argmax(best_accuracies)]
overall_best_hyperparams = hyperparams[np.argmax(best_accuracies)]
cnn = CNN_Spectral_Pool(M=overall_best_hyperparams['M'],
                        num_output=10,
                        verbose=False,
                        learning_rate=overall_best_hyperparams['learning_rate'],
                        l2_norm=overall_best_hyperparams['l2_norm'],
                        lr_reduction_factor=0.5,
                        lr_reduction_epochs=[11,21,31,41],
                        gamma=overall_best_hyperparams['gamma'])
cnn.calc_test_accuracy(xtest, ytest, 'hyperparam_search/{0}'.format(overall_best_model))
# Out:
# Building tf graph...
# (?, 10)
# number of batches for testing: 20
# Loading pre-trained model
# INFO:tensorflow:Restoring parameters from model/hyperparam_search/hyperparam_search_1513530707.2960517
# Test accuracy: 63.170
